# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/LUNA/
# Out:
# /content/drive/MyDrive/LUNA

# %%
# !wget https://zenodo.org/record/3723295/files/annotations.csv
# Out:
# --2021-06-07 15:41:26--  https://zenodo.org/record/3723295/files/annotations.csv
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136986 (134K) [text/plain]
# Saving to: ‘annotations.csv’
#
# annotations.csv     100%[===================>] 133.78K   282KB/s    in 0.5s
#
# 2021-06-07 15:42:03 (282 KB/s) - ‘annotations.csv’ saved [136986/136986]

# %%
# !wget https://zenodo.org/record/3723295/files/candidates.csv
# Out:
# --2021-06-07 15:45:04--  https://zenodo.org/record/3723295/files/candidates.csv
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55427881 (53M) [text/plain]
# Saving to: ‘candidates.csv’
#
# candidates.csv      100%[===================>]  52.86M  15.2MB/s    in 4.6s
#
# 2021-06-07 15:45:14 (11.6 MB/s) - ‘candidates.csv’ saved [55427881/55427881]

# %%
# !wget https://zenodo.org/record/3723295/files/candidates_V2.zip
# Out:
# --2021-06-07 15:46:43--  https://zenodo.org/record/3723295/files/candidates_V2.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11439452 (11M) [application/octet-stream]
# Saving to: ‘candidates_V2.zip’
#
# candidates_V2.zip   100%[===================>]  10.91M  6.21MB/s    in 1.8s
#
# 2021-06-07 15:46:52 (6.21 MB/s) - ‘candidates_V2.zip’ saved [11439452/11439452]

# %%
# !wget https://zenodo.org/record/3723295/files/evaluationScript.zip
# !wget https://zenodo.org/record/3723295/files/sampleSubmission.csv
# Out:
# --2021-06-07 15:48:23--  https://zenodo.org/record/3723295/files/evaluationScript.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21803068 (21M) [application/octet-stream]
# Saving to: ‘evaluationScript.zip.1’
#
# evaluationScript.zi 100%[===================>]  20.79M  8.75MB/s    in 2.4s
#
# 2021-06-07 15:48:27 (8.75 MB/s) - ‘evaluationScript.zip.1’ saved [21803068/21803068]
#
# --2021-06-07 15:48:27--  https://zenodo.org/record/3723295/files/sampleSubmission.csv
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 740 [text/plain]
# Saving to: ‘sampleSubmission.csv’
#
# sampleSubmission.cs 100%[===================>]     740  --.-KB/s    in 0s
#
# 2021-06-07 15:48:28 (80.5 MB/s) - ‘sampleSubmission.csv’ saved [740/740]

# %%
# !wget https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip
# !wget https://zenodo.org/record/3723295/files/subset0.zip
# Out:
# --2021-06-07 15:52:06--  https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303871549 (290M) [application/octet-stream]
# Saving to: ‘seg-lungs-LUNA16.zip’
#
# seg-lungs-LUNA16.zi 100%[===================>] 289.79M  18.0MB/s    in 18s
#
# 2021-06-07 15:52:26 (16.2 MB/s) - ‘seg-lungs-LUNA16.zip’ saved [303871549/303871549]
#
# --2021-06-07 15:52:26--  https://zenodo.org/record/3723295/files/subset0.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6811924508 (6.3G) [application/octet-stream]
# Saving to: ‘subset0.zip’
#
# subset0.zip         100%[===================>]   6.34G  16.0MB/s    in 6m 41s
#
# 2021-06-07 15:59:08 (16.2 MB/s) - ‘subset0.zip’ saved [6811924508/6811924508]

# %%
# !wget https://zenodo.org/record/3723295/files/subset1.zip
# !wget https://zenodo.org/record/3723295/files/subset2.zip
# !wget https://zenodo.org/record/3723295/files/subset3.zip
# !wget https://zenodo.org/record/3723295/files/subset4.zip
# !wget https://zenodo.org/record/3723295/files/subset5.zip
# !wget https://zenodo.org/record/3723295/files/subset6.zip
# Out:
# --2021-06-07 15:59:10--  https://zenodo.org/record/3723295/files/subset1.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6334778552 (5.9G) [application/octet-stream]
# Saving to: ‘subset1.zip’
#
# subset1.zip         100%[===================>]   5.90G  17.6MB/s    in 7m 55s
#
# 2021-06-07 16:07:06 (12.7 MB/s) - ‘subset1.zip’ saved [6334778552/6334778552]
#
# --2021-06-07 16:07:06--  https://zenodo.org/record/3723295/files/subset2.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7257937108 (6.8G) [application/octet-stream]
# Saving to: ‘subset2.zip’
#
# subset2.zip         100%[===================>]   6.76G  17.8MB/s    in 8m 43s
#
# 2021-06-07 16:15:50 (13.2 MB/s) - ‘subset2.zip’ saved [7257937108/7257937108]
#
# --2021-06-07 16:15:50--  https://zenodo.org/record/3723295/files/subset3.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6896620114 (6.4G) [application/octet-stream]
# Saving to: ‘subset3.zip’
#
# subset3.zip         100%[===================>]   6.42G  17.7MB/s    in 7m 48s
#
# 2021-06-07 16:23:40 (14.0 MB/s) - ‘subset3.zip’ saved [6896620114/6896620114]
#
# --2021-06-07 16:23:40--  https://zenodo.org/record/3723295/files/subset4.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6856144330 (6.4G) [application/octet-stream]
# Saving to: ‘subset4.zip’
#
# subset4.zip         100%[===================>]   6.38G  17.5MB/s    in 8m 14s
#
# 2021-06-07 16:31:56 (13.2 MB/s) - ‘subset4.zip’ saved [6856144330/6856144330]
#
# --2021-06-07 16:31:56--  https://zenodo.org/record/3723295/files/subset5.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6610460097 (6.2G) [application/octet-stream]
# Saving to: ‘subset5.zip’
#
# subset5.zip         100%[===================>]   6.16G  17.5MB/s    in 8m 59s
#
# 2021-06-07 16:40:56 (11.7 MB/s) - ‘subset5.zip’ saved [6610460097/6610460097]
#
# --2021-06-07 16:40:56--  https://zenodo.org/record/3723295/files/subset6.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6531050274 (6.1G) [application/octet-stream]
# Saving to: ‘subset6.zip’
#
# subset6.zip         100%[===================>]   6.08G  17.5MB/s    in 12m 18s
#
# 2021-06-07 16:53:15 (8.44 MB/s) - ‘subset6.zip’ saved [6531050274/6531050274]

# %%
# !wget https://zenodo.org/record/4121926/files/subset7.zip
# !wget https://zenodo.org/record/4121926/files/subset8.zip
# !wget https://zenodo.org/record/4121926/files/subset9.zip
# Out:
# --2021-06-08 13:05:35--  https://zenodo.org/record/4121926/files/subset7.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6313598213 (5.9G) [application/octet-stream]
# Saving to: ‘subset7.zip’
#
# subset7.zip         100%[===================>]   5.88G  9.36MB/s    in 10m 47s
#
# 2021-06-08 13:16:24 (9.31 MB/s) - ‘subset7.zip’ saved [6313598213/6313598213]
#
# --2021-06-08 13:16:24--  https://zenodo.org/record/4121926/files/subset8.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6025767505 (5.6G) [application/octet-stream]
# Saving to: ‘subset8.zip’
#
# subset8.zip         100%[===================>]   5.61G  10.2MB/s    in 11m 13s
#
# 2021-06-08 13:27:39 (8.54 MB/s) - ‘subset8.zip’ saved [6025767505/6025767505]
#
# --2021-06-08 13:27:40--  https://zenodo.org/record/4121926/files/subset9.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6699650017 (6.2G) [application/octet-stream]
# Saving to: ‘subset9.zip’
#
# subset9.zip         100%[===================>]   6.24G  9.34MB/s    in 12m 11s
#
# 2021-06-08 13:39:53 (8.74 MB/s) - ‘subset9.zip’ saved [6699650017/6699650017]

# %%
!7z x subset1.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6334778552 bytes (6042 MiB)
#
# Extracting archive: subset1.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset1.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6334778552
# 64-bit = +
#
# 100% 177 - subset1/1.3.6.1.4.1.14519.5.2 . 64865033574190975654369557.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x subset2.zip
!7z x subset3.zip
!7z x subset4.zip
!7z x subset5.zip
!7z x subset6.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7257937108 bytes (6922 MiB)
#
# Extracting archive: subset2.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset2.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 7257937108
# 64-bit = +
#
# 100% 177 - subset2/1.3.6.1.4.1.14519.5.2 . 52370561266624992539111877.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6896620114 bytes (6578 MiB)
#
# Extracting archive: subset3.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset3.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6896620114
# 64-bit = +
#
# 100% 177 - subset3/1.3.6.1.4.1.14519.5.2 . 26625618184773401026809852.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6856144330 bytes (6539 MiB)
#
# Extracting archive: subset4.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset4.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6856144330
# 64-bit = +
#
# 100% 177 - subset4/1.3.6.1.4.1.14519.5.2 . 35939545691201820711078950.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6610460097 bytes (6305 MiB)
#
# Extracting archive: subset5.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset5.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6610460097
# 64-bit = +
#
# 100% 177 - subset5/1.3.6.1.4.1.14519.5.2 . 11151772797848993829243183.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6531050274 bytes (6229 MiB)
#
# Extracting archive: subset6.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset6.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6531050274
# 64-bit = +
#
# 100% 177 - subset6/1.3.6.1.4.1.14519.5.2 . 88628308192728558382581802.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x subset7.zip
!7z x subset8.zip
!7z x subset9.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6313598213 bytes (6022 MiB)
#
# Extracting archive: subset7.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset7.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6313598213
# 64-bit = +
#
# 100% 177 - subset7/1.3.6.1.4.1.14519.5.2 . 59772950022352718462251777.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6025767505 bytes (5747 MiB)
#
# Extracting archive: subset8.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset8.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6025767505
# 64-bit = +
#
# 100% 175 - subset8/1.3.6.1.4.1.14519.5.2 . 11074084993415992563148335.raw
#
# Archives with Errors: 1
#
# Open Errors: 1
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6699650017 bytes (6390 MiB)
#
# Extracting archive: subset9.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = subset9.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6699650017
# 64-bit = +
#
# 100% 175 - subset9/1.3.6.1.4.1.14519.5.2 . 29570505893110165820050204.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x candidates_V2.zip
!7z x evaluationScript.zip
!7z x seg-lungs-LUNA16.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 11439452 bytes (11 MiB)
#
# Extracting archive: candidates_V2.zip
# --
# Path = candidates_V2.zip
# Type = zip
# Physical Size = 11439452
#
# Everything is Ok
#
# Size:       72058556
# Compressed: 11439452
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 21803068 bytes (21 MiB)
#
# Extracting archive: evaluationScript.zip
# --
# Path = evaluationScript.zip
# Type = zip
# Physical Size = 21803068
#
# Everything is Ok
#
# Folders: 5
# Files: 14
# Size:       93234653
# Compressed: 21803068
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 303871549 bytes (290 MiB)
#
# Extracting archive: seg-lungs-LUNA16.zip
# --
# Path = seg-lungs-LUNA16.zip
# Type = zip
# Physical Size = 303871549
#
# Everything is Ok
#
# Files: 1776
# Size:       459546573
# Compressed: 303871549

# %%
import pandas as pd
df_candidates = pd.read_csv('candidates.csv')
df_candidates.head()
# Out:
#                                            seriesuid  coordX  ...  coordZ  class
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -56.08  ... -311.92      0
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...   53.21  ... -245.17      0
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.66  ... -286.62      0
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -33.66  ... -308.41      0
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  -32.25  ... -362.51      0
#
# [5 rows x 5 columns]

# %%
df_candidates['class'].value_counts()
# Out:
# 0    549714
# 1      1351
# Name: class, dtype: int64

# %%
df_annotations = pd.read_csv('annotations.csv')
df_annotations.head()
# Out:
#                                            seriesuid  ...  diameter_mm
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  ...     5.651471
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  ...     4.224708
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...  ...     5.786348
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  ...     8.143262
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  ...    18.545150
#
# [5 rows x 5 columns]
